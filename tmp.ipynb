# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "dataset/task_ABC_D/training/scene_info.npy"
scene_info = np.load(path, allow_pickle=True)
print(scene_info.item())
# Out:
# {'calvin_scene_B': [0, 598909], 'calvin_scene_C': [598910, 1191338], 'calvin_scene_A': [1191339, 1795044]}

# %%
path = "dataset/calvin_debug_dataset/training/scene_info.npy"
scene_info = np.load(path, allow_pickle=True)
print(scene_info)
# Out:
# {'calvin_scene_D': [358482, 361252]}

# %%
path = "dataset/calvin_debug_dataset/validation/ep_start_end_ids.npy"
ep_start_end_ids = np.load(path, allow_pickle=True)
print(ep_start_end_ids)
# Out:
# [[553567 555241]]

# %%
path = 'dataset/calvin_debug_dataset/validation/lang_annotations/auto_lang_ann.npy'
auto_lang_ann = np.load(path, allow_pickle=True).item()
print(auto_lang_ann['language'].keys())
print(auto_lang_ann['language']['task'])
print(auto_lang_ann['info']['indx'])
print(auto_lang_ann['language']['emb'].shape)
# Out:
# dict_keys(['ann', 'task', 'emb'])
# ['lift_red_block_table', 'turn_on_lightbulb', 'lift_blue_block_slider', 'lift_blue_block_slider', 'turn_off_lightbulb', 'place_in_slider', 'push_pink_block_right', 'lift_blue_block_slider']
# [(554046, 554110), (553636, 553700), (553693, 553757), (553691, 553755), (554474, 554538), (554110, 554145), (553916, 553961), (553701, 553765)]
# (8, 1, 384)

# %%
path = "dataset/calvin_debug_dataset/training/episode_0358482.npz"
data = np.load(path)
print(list(data.keys()))
data['actions'], data['rel_actions'], data['robot_obs'], data['scene_obs']
# Out:
# ['actions', 'rel_actions', 'robot_obs', 'scene_obs', 'rgb_static', 'rgb_gripper', 'rgb_tactile', 'depth_static', 'depth_gripper', 'depth_tactile']
# (array([ 0.10014743, -0.09120568,  0.57087628,  3.09732095,  0.02088518,
#          1.50079385,  1.        ]),
#  array([-1.07006856e-02,  1.15504107e-02,  1.77918208e-04, -9.64466816e-02,
#          7.23821376e-04,  8.83792502e-04,  1.00000000e+00]),
#  array([ 0.10036145, -0.09143668,  0.57087272,  3.10214328,  0.02084899,
#          1.50074966,  0.07999974, -0.59011412,  0.89867477,  1.74402731,
#         -1.84388101, -0.92408956,  1.59611532,  0.58673495,  1.        ]),
#  array([ 8.80929092e-05, -1.53721945e-34,  0.00000000e+00,  1.93132547e-17,
#          0.00000000e+00,  0.00000000e+00,  2.32403619e-01, -4.04295856e-02,
#          4.59990009e-01,  4.12287744e-08, -8.05700103e-09, -2.17741510e+00,
#         -2.83642665e-01,  8.05351014e-02,  4.60989238e-01, -1.10251078e-05,
# ...

# %%
path = "dataset/calvin_debug_dataset/training/episode_0358482.npz"
data = np.load(path)
plt.imshow(data['rgb_static'])
